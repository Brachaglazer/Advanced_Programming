# %% [markdown]
# <a href="https://colab.research.google.com/github/Brachaglazer/Advanced_Programming/blob/Class9/inheritance_polymorphism_quiz_2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Quiz: Inheritance and Polymorphism in Python
#
# **Estimated time for a fast student:** about 30 minutes
#
# ## Directions
# Complete this quiz in the cells provided.
#
# ## Topics Covered
# - inheritance
# - parent and child classes
# - method overriding
# - polymorphism
# - identifying shared vs specialized behavior
#
# ## Rules
# - Write your own code.
# - Keep your work clear and readable.
# - Run all cells before submitting.

# %% [markdown]
# ## Question 1: Inheritance with Employees
#
# Create a parent class named `Employee`.
#
# ### `Employee` must:
# - store an employee name
# - store a department
# - include a method named `work()` that returns a general work message
#
# Then create a child class named `Manager`.
#
# ### `Manager` must:
# - inherit from `Employee`
# - use the parent constructor
# - override `work()` so that it returns a manager-specific message
#
# ### After writing your classes
# Create a `Manager` object and demonstrate that:
# - the object stores its data correctly
# - the overridden `work()` method is being used

# %%
# Write your answer for Question 1 here.
class Employee:
  def __init__(self, name: str, department: str) -> None:
    self.name = name
    self.department = department

  def work(self) -> str:
    return f"{self.name} is assigned to work in the {self.department} department today."

class Manager(Employee):
  def __init__(self, name, department) -> None:
    super().__init__(name, department)

  def work(self):
    return f"{self.name} is the manager of the {self.department} department."

# %%
manager = Manager("Bill", "Technology")
print(manager.name, manager.department)
print(manager.work())
# Out:
# Bill Technology
# Bill is the manager of the Technology department.

# %% [markdown]
# ## Question 2: Choose What Belongs in the Parent
#
# Below is a group of possible attributes and behaviors for electronic devices:
#
# - brand
# - battery_percent
# - charge()
# - take_photo()
# - make_call()
#
# Create a parent class named `Device` using only the information that should reasonably be shared by many devices.
#
# Then create a child class named `Phone`.
#
# ### Requirements
# - `Device` should store shared data and include at least one shared behavior
# - `Phone` should inherit from `Device`
# - `Phone` should add or override behavior that makes sense for a phone
#
# ### After writing your classes
# Create a `Phone` object and demonstrate that inherited behavior works correctly.

# %%
# Write your answer for Question 2 here.
class Device:
  def __init__(self, battery_percent: int) -> None:
    self.battery_percent = battery_percent

  def charge(self) -> str:
    self.battery_percent = 100
    return self.battery_percent

  def take_photo(self) -> str:
    return f"click"

class Phone(Device):
  def __init__(self, battery_percent: int) -> None:
    super().__init__(battery_percent)

  def make_call(self) -> str:
    return f"Ding a ling"

# %%
phone = Phone(33)
device = Device(54)

print(phone.battery_percent)
print(phone.charge())
print(phone.take_photo())
print(phone.make_call())
# Out:
# 33
# 100
# click
# Ding a ling

# %% [markdown]
# ## Question 3: Polymorphism with School Roles
#
# Create a parent class named `SchoolMember` with a method named `introduce()`.
#
# Then create these child classes:
# - `Teacher`
# - `Student`
#
# Each child class should override `introduce()` in its own way.
#
# ### Then:
# 1. Create one `Teacher` object and one `Student` object
# 2. Store them together in a list
# 3. Use one loop to call `introduce()` on each object
#
# ## Goal
# Your output should clearly demonstrate polymorphism.

# %%
# Write your answer for Question 3 here.
class SchoolMember:
  def __init__(self, name: str, floor: int) -> None:
    self.name = name
    self.floor = floor

  def introduce(self) -> str:
    return f"Hi, my name is {self.name}. I spend my time on floor {self.floor}."

class Teacher(SchoolMember):
  def __init__(self, name: str, floor: int) -> None:
    super().__init__(name, floor)

  def introduce(self) -> str:
    return f"Hi, my name is Professor {self.name}. I teach on floor {self.floor}."

class Student(SchoolMember):
  def __init__(self, name: str, floor: int) -> None:
    super().__init__(name, floor)

  def introduce(self) -> None:
    return f"Hi my name is {self.name}. I learn on floor {self.floor}"

# %%
teacher = Teacher("Sara", 7)
student = Student("Rivka", 3)

school = [teacher, student]

for s in school:
  print(s.introduce())
# Out:
# Hi, my name is Professor Sara. I teach on floor 7.
# Hi my name is Rivka. I learn on floor 3

# %% [markdown]
# ## Question 4: Method Overriding Analysis
#
# Look at the code below.
#
# ```python
# class Appliance:
#     def start(self):
#         return "The appliance starts."
#
# class Blender(Appliance):
#     def start(self):
#         return "The blender spins."
# ```
#
# Answer both questions in complete sentences:
#
# 1. Why is `Blender` considered a child class?
# 2. What is different about calling `start()` on a `Blender` object versus an `Appliance` object?

# %% [markdown]
# Write your answer for Question 4 here.
# 1. Blender is considered a child class becasue it inherits from the parent class called Appliance, by putting it in the () when naming the class.
# 2. The Appliance object will return the string in its start method ("The appliance starts.") while the blender object will return the string defined in its own class ("The blender spins.") because its own method overrides the parents method.

# %% [markdown]
# ## Question 5: Short Design Reflection
#
# Answer in complete sentences:
#
# Suppose you are creating these classes:
#
# - `Book`
# - `EBook`
# - `AudioBook`
#
# 1. What information or behavior would you place in the parent class?
# 2. Give one example of a method that a child class might override.

# %% [markdown]
# Write your answer for Question 5 here.
# 1. I would place the title and author attributes in the parent class. I would place the purchase method in the parent class as well.

# %%
# only to demontrate the override
class Parent:
  def contributors(self):
    return f"{self.title} is written by {self.author} and published by {self.publisher}."


class AudioBook(Parent):
  def contributors(self):
    return f"{self.title} is written by {self.author} and published by {self.publisher} and recorded by {self.recorded_by}."

# %% [markdown]
# ## Bonus (Optional)
#
# Create your own small inheritance example with:
# - 1 parent class
# - 2 child classes
# - 1 overridden method
# - 1 loop that demonstrates polymorphism

# %%
# Write your bonus answer here.
class Food:
  def __init__(self, name: str, color: str) -> None:
    self.name = name
    self.color = color

  def what_color(self) -> str:
    return f"{self.name} has a perfect {self.color} color."

class Apple(Food):
  def __init__(self, name: str, color: str) -> None:
    super().__init__(name, color)

  def what_color(self) -> None:
    return f"{self.name} comes in a few different colors, very often it is {self.color}."

class Mango(Food):
  def __init__(self, name: str, color: str) -> None:
    super().__init__(name, color)

  def what_color(self) -> None:
    return f"{self.name} is a mix of colors, {self.color} is one of the very noticeable ones."

# %%
apple = Apple("Golden Crisp Apples", "yellow")
mango = Mango("Mangos", "yellow")

food = [apple, mango]
for f in food:
  print(f.name, f.color)
  print(f.what_color())
# Out:
# Golden Crisp Apples yellow
# Golden Crisp Apples comes in a few different colors, very often it is yellow.
# Mangos yellow
# Mangos is a mix of colors, yellow is one of the very noticeable ones.

# %% [markdown]
# ## Submission Checklist
#
# Before submitting, make sure:
# - your child classes inherit correctly
# - your overridden methods behave differently from the parent version
# - your polymorphism example uses a list and a loop
# - your notebook runs without errors
