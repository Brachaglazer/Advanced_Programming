# %% [markdown]
# <a href="https://colab.research.google.com/github/Brachaglazer/Advanced_Programming/blob/Class3_Lab/MCON_232_Dictionaries_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Bracha Glazer
# ## Topic : Dictionaries Lab

# %%
my_dict = {
            "name" : "Fuzzy",
            "age" : 12,
            "pet-type" : "dog",
            "fur-color" : "brown"
            }

my_dict["eye color"] = "brown"
print(my_dict)
print(f'pet age: {my_dict["age"]}')

print(f'{my_dict["age"]=}')

try:
  print(my_dict["hair"])
except KeyError as ke:
  print("Key not found", ke)
# Out:
# {'name': 'Fuzzy', 'age': 12, 'pet-type': 'dog', 'fur-color': 'brown', 'eye color': 'brown'}
# pet age: 12
# my_dict["age"]=12
# Key not found 'hair'

# %%
"age" in my_dict
"hair" not in my_dict
"dog" in my_dict
# Out:
# False

# %%
my_dict2 = {}
my_dict2["cat"] = "Polly"

my_array[3] = 4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1943537761.py in <cell line: 0>()
#       2 my_dict2["cat"] = "Polly"
#       3
# ----> 4 my_array[3] = 4
#
# NameError: name 'my_array' is not defined
